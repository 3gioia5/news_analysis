# %%
import numpy as np
import pandas as pd
import re

# %% [markdown]
# 텍스트 데이터 전처리 순서
#
# 1. 특수문자 대체, 중복 띄어쓰기 제거
# 2. 토큰화
# 3. 표제어 추출
# 4. 불용어 제거
# 5. 빈도수 계산
# 6. 시각화

# %%
df = pd.read_csv('dataset_kr.csv')

# %%
df
# Out:
#                                                 기사 제목               발행일  \
# 0   «Hellbound», la nuova «Squid Game»? Un altro h...  25 novembre 2021
# 1                                 Corea, che passione   7 novembre 2021
# 2   Squid game, anche a Napoli esplode la mania. A...    9 ottobre 2021
# 3   «Squid Game», tutto quello che c’è da sapere s...    6 OTTOBRE 2021
# 4         Altre due star morte misteriosamente a Seul   26 gennaio 2021
# ..                                                ...               ...
# 75  BTS, ecco come i campioni del K-pop potranno e...    19 AGOSTO 2022
# 76  Pachinko', il riscatto di una vita migrante. Y...     28 MARZO 2022
# 77       Han Kang: il romanzo è vivo e abita in Corea  21 FEBBRAIO 2021
# 78  POP ALLA COREANA, COSÌ IL FENOMENO K-POP CONQU...   23 gennaio 2022
# 79  Korea Week, rassegna di film e docu, molti ine...  05 novembre 2021
#
#                                                    내용                  언론사  \
# 0   Un’inspiegabile maledizione in formato video i...  corriere della sera
# 1   Squid Game, la serie televisiva dei record, am...  corriere della sera
# 2   Nel giro di pochi giorni è diventato uno dei c...  corriere della sera
# 3   “Squid Game”, un trionfo inatteso\nSenza inves...  corriere della sera
# 4   Il lato oscuro dello star system sudcoreano ha...  corriere della sera
# ..                                                ...                  ...
# 75  I sette ragazzi del gruppo di K-pop coreano BT...        la repubblica
# 76  Ottant’anni di storia familiare attraverso Cor...        la repubblica
# 77  \nTalvolta oggi, in Italia, abbiamo l'impressi...        la repubblica
# 78  La Corea è trend: il film Oscar Parasite di Bo...                 ANSA
# 79  Sarà un seminario dell'Università La Sapienza ...                 ANSA
#
#                                                    출처
# 0   https://www.corriere.it/esteri/21_novembre_25/...
# 1   https://corrieredelveneto.corriere.it/veneto/c...
# 2   https://corrieredelmezzogiorno.corriere.it/nap...
# 3   https://www.corriere.it/spettacoli/cinema-seri...
# 4   https://www.corriere.it/esteri/21_gennaio_26/a...
# ..                                                ...
# 75  https://www.repubblica.it/spettacoli/cinema/20...
# 76  https://www.repubblica.it/serietv/appletvplus/...
# 77  https://www.repubblica.it/robinson/2021/02/21/...
# 78  https://www.ansa.it/canale_lifestyle/notizie/t...
# 79  https://www.ansa.it/sito/notizie/cultura/cinem...
#
# [80 rows x 5 columns]

# %%
# 데이터 결측값 제거

print("데이터 결측값 제거 전 col. 수: {}".format(df.shape[0]))
df = df.dropna(axis=0)
print("데이터 결측값 제거 후 col. 수: {}".format(df.shape[0]))
# Out:
# 데이터 결측값 제거 전 col. 수: 80
# 데이터 결측값 제거 후 col. 수: 80

# %%
# 개행문자 제거, 전체 텍스트 소문자로 통일, 특수문자 제거
def preprocessing(text):
    text = str(text)
    
    text.replace("\n", " ")
    
    text = text.lower()
    
    text = re.sub(r"[^\w]", " ", text)
    return text if text else None


# 공란 처리
def delete_space(text):
    text = ' '.join(text.split())
    return text

# %%
df['내용'].head(5)
# Out:
# 0    Un’inspiegabile maledizione in formato video i...
# 1    Squid Game, la serie televisiva dei record, am...
# 2    Nel giro di pochi giorni è diventato uno dei c...
# 3    “Squid Game”, un trionfo inatteso\nSenza inves...
# 4    Il lato oscuro dello star system sudcoreano ha...
# Name: 내용, dtype: object

# %%
df['내용'] = df[['내용']].apply(lambda x: preprocessing(x['내용']), axis=1)

df['내용'].head(5)
# Out:
# 0    un inspiegabile maledizione in formato video i...
# 1    squid game  la serie televisiva dei record  am...
# 2    nel giro di pochi giorni è diventato uno dei c...
# 3     squid game   un trionfo inatteso senza invest...
# 4    il lato oscuro dello star system sudcoreano ha...
# Name: 내용, dtype: object

# %%
df['내용'] = df[['내용']].apply(lambda x: delete_space(x['내용']), axis=1)

df['내용'].head(5)
# Out:
# 0    un inspiegabile maledizione in formato video i...
# 1    squid game la serie televisiva dei record amat...
# 2    nel giro di pochi giorni è diventato uno dei c...
# 3    squid game un trionfo inatteso senza investire...
# 4    il lato oscuro dello star system sudcoreano ha...
# Name: 내용, dtype: object

# %%
# 불용어 제거 전 빈도 분석
from collections import Counter

result = " ".join(df['내용'].tolist())
count = Counter(result.split(" "))

count.most_common(15)
# Out:
# [('di', 1505),
#  ('e', 1045),
#  ('la', 871),
#  ('il', 848),
#  ('che', 775),
#  ('un', 694),
#  ('in', 661),
#  ('a', 594),
#  ('è', 581),
#  ('per', 479),
#  ('i', 447),
#  ('del', 446),
#  ('una', 394),
#  ('con', 361),
#  ('l', 334)]

# %%
# spaCy 모듈 import
import spacy
from spacy.lang.it.examples import sentences

# %%
nlp = spacy.load('it_core_news_sm')

# %%
# 토큰화
def tokenizer(data):
    doc = nlp(data)
    tokens = list()
    for token in doc:
        tokens.append(token.text)
    return tokens

tokenized = []
for i in range(len(df)):
    tokenized.append(tokenizer(df['내용'][i]))
print(tokenized)
# Out:
# [['un', 'inspiegabile', 'maledizione', 'in', 'formato', 'video', 'incolla', 'allo', 'schermo', 'milioni', 'di', 'utenti', 'occidentali', 'come', 'drogati', 'dal', 'sangue', 'non', 'possono', 'fare', 'a', 'meno', 'di', 'scene', 'sempre', 'più', 'splatter', 'trame', 'sempre', 'più', 'nichiliste', 'poteri', 'sempre', 'più', 'sanguinosi', 'e', 'ne', 'vogliono', 'ancora', 'e', 'ancora', 'la', 'dipendenza', 'è', 'così', 'forte', 'che', 'non', 'li', 'scoraggia', 'nemmeno', 'l', 'audio', 'i', 'filmati', 'dell', 'orrore', 'sono', 'solamente', 'in', 'coreano', 'per', 'chi', 'non', 'si', 'rassegna', 'c', 'è', 'al', 'massimo', 'il', 'doppiaggio', 'in', 'inglese', 'ha', 'un', 'che', 'di', 'trama', 'horror', 'a', 'sua', 'volta', 'la', 'cronaca', 'dell', 'ascesa', 'irresistibile', 'di', 'squid', 'game', 'prima', 'e', 'ora', 'della', 'serie', 'ancora', 'più', 'violenta', 'e', 'cupa', 'hellbound', 'sempre', 'sudcoreana', 'ora', 'ai', 'vertici', 'delle', 'classifiche', 'd', 'ascolto', 'in', 'streaming', 'dopo', '46', 'giorni', 'consecutivi', 'in', 'cui', 'la', 'più', 'vista', 'di', 'tutte', 'le', 'serie', 'netflix', 'è', 'stata', 'squid', 'game', 'ora', 'il', 'primato', 'mondiale', 'va', 'a', 'hellbound', 'sei', 'puntate', 'di', 'orrore', 'in', 'cui', 'tre', 'terrificanti', 'demoni', 'dall', 'aria', 'di', 'scimmioni', 'annunciati', 'da', 'un', 'angelo', 'profeta', 'vanno', 'a', 'prendere', 'a', 'casa', 'le', 'persone', 'che', 'hanno', 'peccato', 'e', 'le', 'uccidono', 'sulla', 'pubblica', 'piazza', 'con', 'violenze', 'molto', 'scenografiche', 'netflix', 'dichiara', 'che', 'è', 'stata', 'vista', 'in', 'tutto', 'il', 'mondo', 'per', '781', 'milioni', 'di', 'ore', 'è', 'uscita', 'da', '5', 'giorni', 'i', 'dati', 'd', 'ascolto', 'di', 'netflix', 'sono', 'a', 'lungo', 'stati', 'coperti', 'dal', 'più', 'assoluto', 'e', 'controverso', 'mistero', 'da', 'poco', 'la', 'piattaforma', 'ha', 'acconsentito', 'a', 'divulgare', 'ogni', 'settimana', 'una', 'top', '10', 'dei', 'film', 'e', 'delle', 'serie', 'più', 'visti', 'nel', 'mondo', 'e', 'anche', 'una', 'mappa', 'degli', 'ascolti', 'scorporati', 'per', 'paese', 'in', 'italia', 'questa', 'settimana', 'spadroneggia', 'per', 'esempio', 'la', 'serie', 'di', 'zerocalcare', 'strappare', 'lungo', 'i', 'bordi', 'ma', 'in', '35', 'classifiche', 'nazionali', 'la', 'più', 'vista', 'sarebbe', 'proprio', 'hellbound', 'ai', 'primi', 'posti', 'in', 'circa', '80', 'paesi', 'hellbound', 'è', 'diretta', 'da', 'yeong', 'san', 'ho', 'la', 'cui', 'opera', 'più', 'celebre', 'in', 'europa', 'è', 'il', 'film', 'train', 'to', 'busan', 'in', 'cui', 'nel', '2016', 'pronosticava', 'un', 'virus', 'misterioso', 'e', 'un', 'lockdown', 'in', 'tutta', 'la', 'corea', 'del', 'sud', 'la', 'trama', 'di', 'hellbound', 'è', 'cupa', 'già', 'nei', 'primi', 'tre', 'minuti', 'assistiamo', 'a', 'una', 'dimostrazione', 'della', 'legge', 'divina', 'cioè', 'all', 'arrivo', 'di', 'tre', 'demoni', 'dalle', 'fattezze', 'scimmiesche', 'che', 'uccidono', 'e', 'carbonizzano', 'le', 'loro', 'vittime', 'cioè', 'uomini', 'che', 'hanno', 'peccato', 'e', 'a', 'cui', 'nei', 'giorni', 'precedenti', 'è', 'apparso', 'un', 'angelo', 'profeta', 'a', 'comunicare', 'ora', 'e', 'giorno', 'dell', 'esecuzione', 'attorno', 'a', 'questi', 'fenomeni', 'diventa', 'ben', 'presto', 'nota', 'una', 'setta', 'paracristiana', 'quella', 'della', 'nuova', 'verità', 'con', 'leader', 'carismatici', 'e', 'quasi', 'da', 'subito', 'frange', 'estremiste', 'di', 'violenti', 'picchiatori', 'la', 'società', 'coreana', 'terrorizzata', 'diventa', 'rapidamente', 'una', 'società', 'di', 'fanatici', 'religiosi', 'e', 'bigotti', 'ma', 'che', 'cosa', 'in', 'storie', 'come', 'questa', 'o', 'quella', 'di', 'squid', 'game', 'tiene', 'incollati', 'allo', 'schermo', 'milioni', 'di', 'spettatori', 'occidentali', 'gli', 'ingredienti', 'di', 'un', 'successo', 'sono', 'sempre', 'misteriosi', 'eppure', 'il', 'successo', 'del', 'k', 'drama', 'cioè', 'del', 'cinema', 'sudcoreano', 'spesso', 'di', 'genere', 'ma',  ...

# %%
import collections

# 표제어 추출
def lemmatizer(data):
    doc = nlp(data)
    tokens = []
    for token in doc:
        tokens.append(token.lemma_)
    return tokens


lemmartized = []
for i in range(len(df)):
    lemmartized.append(lemmatizer(df['내용'][i]))

# print(lemmartized)

result = sum(lemmartized, [])

# 단어 개수 계산
counts = collections.Counter(result)

counts.most_common(20)
# Out:
# [('il', 2563),
#  ('di', 1512),
#  ('essere', 1189),
#  ('uno', 1149),
#  ('e', 1081),
#  ('di il', 1048),
#  ('che', 775),
#  ('a', 669),
#  ('in', 661),
#  ('avere', 631),
#  ('a il', 490),
#  ('per', 479),
#  ('in il', 384),
#  ('con', 361),
#  ('non', 331),
#  ('si', 293),
#  ('da', 277),
#  ('l', 269),
#  ('più', 266),
#  ('da il', 217)]

# %%
import nltk
from nltk.corpus import stopwords

nltk.download('stopwords', quiet=True)

sw_it = set(stopwords.words('italian'))
print(sw_it)
# Out:
# {'come', 'aveste', 'fu', 'fummo', 'avresti', 'stavo', 'da', 'perché', 'chi', 'avuto', 'avendo', 'ed', 'stavamo', 'abbiate', 'facemmo', 'tue', 'le', 'starebbero', 'suoi', 'lui', 'faremo', 'con', 'sarebbe', 'facciate', 'faccia', 'stava', 'quale', 'su', 'che', 'avevate', 'dello', 'avrei', 'erano', 'ebbe', 'ai', 'dai', 'quanta', 'avevi', 'facessimo', 'ci', 'siamo', 'faranno', 'stemmo', 'alle', 'del', 'col', 'li', 'avrete', 'farò', 'contro', 'lei', 'questi', 'sareste', 'saranno', 'avrebbe', 'faceva', 'questa', 'queste', 'sugl', 'avremmo', 'avuti', 'avute', 'sia', 'fui', 'gli', 'stanno', 'starei', 'vi', 'stetti', 'starai', 'sarei', 'stando', 'fai', 'stavate', 'dove', 'abbia', 'eri', 'quanto', 'staremmo', 'la', 'dei', 'mia', 'e', 'avrai', 'feci', 'degl', 'io', 'hai', 'dal', 'l', 'nostre', 'sarò', 'sarete', 'dalla', 'stareste', 'nelle', 'sarà', 'furono', 'facevo', 'starò', 'abbiamo', 'una', 'sullo', 'quanti', 'mi', 'all', 'starete', 'è', 'a', 'alla', 'stavano', 'quelle', 'facessi', 'non', 'stette', 'dagl', 'stiate', 'farete', 'allo', 'suo', 'sulla', 'dov', 'fosse', 'ma', 'fosti', 'sto', 'agli', 'sarebbero', 'eravate', 'agl', 'avevamo', 'al', 'sua', 'sue', 'facessero', 'loro', 'ero', 'dallo', 'quella', 'dall', 'essendo', 'ne', 'stiano', 'avesti', 'si', 'mie', 'fecero', 'nella', 'in', 'avuta', 'era', 'dell', 'saremo', 'foste', 'stavi', 'stettero', 'tutto', 'stesti', 'o', 'siete', 'avessi', 'facevi', 'facevate', 'tuoi', 'vostra', 'sarai', 'stessi', 'cui', 'quello', 'farebbe', 'starà', 'nei', 'sugli', 'tra', 'lo', 'staresti', 'saresti', 'fossero', 'ti', 'avrà', 'staranno', 'ad', 'c', 'avevo', 'siano', 'fossimo', 'farei', 'stia', 'mio', 'facendo', 'farai', 'quelli', 'nostri', 'avrebbero', 'nostro', 'vostro', 'coi', 'miei', 'avesse', 'ha', 'sui', 'avremo', 'avessimo', 'faceste', 'nel', 'degli', 'se', 'tuo', 'facesse', 'delle', 'sei', 'vostri', 'facciamo', 'hanno', 'tu', 'sul', 'un', 'stai', 'negl', 'stessero', 'avrò', 'faremmo', 'fossi', 'quante', 'nostra', 'voi', 'fareste', 'sta', 'negli', 'nello', 'avevano', 'vostre', 'steste', 'più', 'farà', 'stessimo', 'siate', 'fanno', 'stiamo', 'abbiano', 'nell', 'eravamo', 'uno', 'avessero', 'saremmo', 'dalle', 'avemmo', 'sono', 'stesse', 'farebbero', 'facesti', 'di', 'ho', 'avete', 'avranno', 'facevano', 'dagli', 'faresti', 'staremo', 'sulle', 'anche', 'facevamo', 'sull', 'facciano', 'fece', 'della', 'noi', 'aveva', 'ebbi', 'ebbero', 'avreste', 'faccio', 'starebbe', 'tutti', 'questo', 'il', 'per', 'i', 'tua'}

# %%
for stopword in sw_it:
    if stopword in counts.keys():
        del counts[stopword]

counts_df_kr = pd.DataFrame(counts.most_common(), columns=['parola', 'totale'])

counts_df_kr.head(20)
# Out:
#      parola  totale
# 0    essere    1189
# 1     di il    1048
# 2     avere     631
# 3      a il     490
# 4     in il     384
# 5     da il     217
# 6       pop     152
# 7      fare     149
# 8      anno     148
# 9     su il     136
# 10    serie     122
# 11     film     121
# 12        k     116
# 13  coreano     111
# 14    altro     106
# 15    molto     105
# 16    corea     104
# 17   potere     103
# 18    primo      97
# 19    mondo      96

# %%
sw_it.update(['essere', 'avere', 'fare', 'potere', 'di il', 'a il', 'in il', 'da il', 'su il'])

for stopword in sw_it:
    if stopword in counts.keys():
        del counts[stopword]

counts_df_kr = pd.DataFrame(counts.most_common(), columns=['parola', 'totale'])
counts_df_kr.to_excel("counts_df_kr.xlsx")

counts_df_kr.head(20)
# Out:
#      parola  totale
# 0       pop     152
# 1      anno     148
# 2     serie     122
# 3      film     121
# 4         k     116
# 5   coreano     111
# 6     altro     106
# 7     molto     105
# 8     corea     104
# 9     primo      97
# 10    mondo      96
# 11   vedere      90
# 12      bts      87
# 13    squid      82
# 14    gioco      80
# 15     solo      78
# 16  milione      76
# 17    stare      73
# 18      due      72
# 19     game      70

# %%
from numpy.random import randint
import matplotlib
import matplotlib.pyplot as plt
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

mask = np.array(Image.open('flag_kr.png'))

wc = WordCloud(background_color="rgb(255, 255, 255)", width=800, height=600, max_words=200, mask=mask,
              color_func=ImageColorGenerator(mask)).generate_from_frequencies(counts)

plt.figure(figsize=(10,10))
plt.axis('off')
plt.imshow(wc, interpolation="bicubic")
plt.savefig('result_kr.png')
plt.show()
